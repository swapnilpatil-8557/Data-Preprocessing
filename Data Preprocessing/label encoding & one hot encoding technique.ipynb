# %% [markdown]
# ## Label Encoding

# %% [markdown]
# ### Titanic Dataset

# %%
import pandas as pd
import seaborn as sns
df=sns.load_dataset('titanic').head()  #loaded titanic dataset
df
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
from sklearn.preprocessing import LabelEncoder #sklearn has module preprocessing in which label encoder is for labeling the data.
le=preprocessing.LabelEncoder()

# %%
le.fit(df['sex'])  #it find out the unique values in sexcolumn & accordingly assign the numerical values.
# Out:
# LabelEncoder()

# %%
df['sex']=le.transform(df['sex'])  #to apply the label encoder over the sex column.

# %%
df #sex column has labeled with male = 1 & female = 0
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500        S  Third    man
# 1         1       1    0  38.0      1      0  71.2833        C  First  woman
# 2         1       3    0  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    0  35.0      1      0  53.1000        S  First  woman
# 4         0       3    1  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %% [markdown]
# ### Dataset - Penguins

# %%
df1=sns.load_dataset('penguins')

# %%
df1.dropna().head()
# Out:
#   species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie       2            39.1           18.7              181.0
# 1  Adelie       2            39.5           17.4              186.0
# 2  Adelie       2            40.3           18.0              195.0
# 4  Adelie       2            36.7           19.3              193.0
# 5  Adelie       2            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 4       3450.0  FEMALE
# 5       3650.0    MALE

# %%
from sklearn.preprocessing import LabelEncoder
le=preprocessing.LabelEncoder()

# %%
le.fit(df1['island'])
# Out:
# LabelEncoder()

# %%
df1['island']=le.transform(df1['island'])

# %%
df1.head(10)
# Out:
#   species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie       2            39.1           18.7              181.0
# 1  Adelie       2            39.5           17.4              186.0
# 2  Adelie       2            40.3           18.0              195.0
# 3  Adelie       2             NaN            NaN                NaN
# 4  Adelie       2            36.7           19.3              193.0
# 5  Adelie       2            39.3           20.6              190.0
# 6  Adelie       2            38.9           17.8              181.0
# 7  Adelie       2            39.2           19.6              195.0
# 8  Adelie       2            34.1           18.1              193.0
# 9  Adelie       2            42.0           20.2              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE
# 5       3650.0    MALE
# 6       3625.0  FEMALE
# 7       4675.0    MALE
# ...

# %% [markdown]
# # HR Dataset

# %%
hrdata=pd.read_excel("C:\\Users\\Snehal\\Desktop\\data science\\datasets\\HRdata.xlsx")
hrdata.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=preprocessing.LabelEncoder()

# %%
le.fit(hrdata['RecruitmentSource'])
hrdata['RecruitmentSource']=le.transform(hrdata['RecruitmentSource'])

# %%
hrdata.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %% [markdown]
# ### Titanic Dataset

# %%
tc=sns.load_dataset('titanic').head()

# %%
l=['sex','class','who','adult_male','alone']

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# #### For encoding the miltiple variables using 'for' loop

# %%
for i in l:
    le=preprocessing.LabelEncoder()
    le.fit(tc[i])
    tc[i]=le.transform(tc[i])

# %%
tc
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class  who  \
# 0         0       3    1  22.0      1      0   7.2500        S      1    0
# 1         1       1    0  38.0      1      0  71.2833        C      0    1
# 2         1       3    0  26.0      0      0   7.9250        S      1    1
# 3         1       1    0  35.0      1      0  53.1000        S      0    1
# 4         0       3    1  35.0      0      0   8.0500        S      1    0
#
#    adult_male deck  embark_town alive  alone
# 0           1  NaN  Southampton    no      0
# 1           0    C    Cherbourg   yes      0
# 2           0  NaN  Southampton   yes      1
# 3           0    C  Southampton   yes      0
# 4           1  NaN  Southampton    no      1

# %% [markdown]
# # One Hot Encoding

# %%
taxis=sns.load_dataset('taxis')
taxis.head()
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
pd.get_dummies(taxis,columns=['payment','color']).head()  #it creates seperate variables for unique values in given column
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total            pickup_zone           dropoff_zone pickup_borough  \
# 0    0.0  12.95        Lenox Hill West    UN/Turtle Bay South      Manhattan
# 1    0.0   9.30  Upper West Side South  Upper West Side South      Manhattan
# 2    0.0  14.16          Alphabet City           West Village      Manhattan
# 3    0.0  36.95              Hudson Sq         Yorkville West      Manhattan
# 4    0.0  13.40           Midtown East         Yorkville West      Manhattan
#
# ...

# %% [markdown]
# ## Dataset - Pune Rent Data

# %%
import pandas as pd
import seaborn as sns
import numpy as np

pune=pd.read_csv("C:\\Users\\Snehal\\Desktop\\data science\\datasets\\pune rent data\\test.csv")
pune.head()
# Out:
#    bedroom  bathrooms    area     furnishing avalable_for  \
# 0        2          2     0.0  Semifurnished          All
# 1        2          2  1050.0  Semifurnished          All
# 2        2          2   900.0  Semifurnished          All
# 3        3          3  1100.0      Furnished  Family Only
# 4        1          1   605.0  Semifurnished  Family Only
#
#                                              address  floor_number  \
# 0       Bella Casa Baner, Baner, , Pune, Maharashtra             1
# 1  Paranjape Blue Ridge, Hinjewadi, , Pune, Mahar...             2
# 2  Simplicity Apartments, Handewadi, , Pune, Maha...             6
# 3  GK Dwarka Queens Park, Rahatani, , Pune, Mahar...             1
# 4  Anandtara Sayajiraje Avenue, Sasane Colony, , ...             4
#
#          facing    floor_type gate_community  ... pooja_room  study_room  \
# 0  No Direction  Not provided             No  ...          0           0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
l=["furnishing","avalable_for","facing","floor_type","gate_community","corner_pro"]

# %%
for i in l:
    le.fit(pune[i])
    pune[i]=le.transform(pune[i])
pune.head()
# Out:
#    bedroom  bathrooms    area  furnishing  avalable_for  floor_number  facing  \
# 0        2          2     0.0           1             0             1       1
# 1        2          2  1050.0           1             0             2       8
# 2        2          2   900.0           1             0             6       1
# 3        3          3  1100.0           0             6             1       0
# 4        1          1   605.0           1             6             4       0
#
#    floor_type  gate_community  corner_pro  ...  pooja_room study_room others  \
# 0           7               0           0  ...           0          0      0
# 1           7               1           1  ...           0          0      0
# 2           7               1           0  ...           0          0      0
# 3           8               1           0  ...           0          0      0
# 4          13               1           1  ...           0          0      1
#
# ...
