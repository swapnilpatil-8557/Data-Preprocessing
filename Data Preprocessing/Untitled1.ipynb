# %%
# !pip install pandas-profiling
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/05/8e/8de486cbd03baba4deef4142bd643a3e7bbe954a784dc1bb17142572d127/packaging-21.3-py3-none-any.whl
# ...
#   Stored in directory: C:\Users\Snehal\AppData\Local\pip\Cache\wheels\43\07\ac\7c5a9d708d65247ac1f94066cf1db075540b85716c30255459
# ...
#   Stored in directory: C:\Users\Snehal\AppData\Local\pip\Cache\wheels\32\3c\c7\b0653122fc94b27b4c60d2260896bb4759e56396c6720d0a6c
# Successfully built htmlmin imagehash
# ...
#   Found existing installation: pandas 0.24.2
#     Uninstalling pandas-0.24.2:
#       Successfully uninstalled pandas-0.24.2
#   Found existing installation: joblib 0.13.2
#     Uninstalling joblib-0.13.2:
#       Successfully uninstalled joblib-0.13.2
#   Found existing installation: scipy 1.2.1
#     Uninstalling scipy-1.2.1:
#       Successfully uninstalled scipy-1.2.1
#   Found existing installation: packaging 19.0
#     Uninstalling packaging-19.0:
#       Successfully uninstalled packaging-19.0
# ...
